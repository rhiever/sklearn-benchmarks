# %% [markdown]
# # First read the 'sklearn-benchmark-data.tsv.gz' file

# %%
import pandas as pd

benchmark_data = pd.read_csv('sklearn-benchmark-data.tsv.gz', sep='\t')
benchmark_data.head()
benchmark_data.rename(columns={'heart-c':'Dataset_Name',
                               'GradientBoostingClassifier':'Method_Name',
                               'loss=exponential,learning_rate=10.0,n_estimators=100,max_depth=3,max_features=sqrt,warm_start=True':
                               'Parameters',
                               '0.723684210526':'Test_Score'},inplace=True)

# %% [markdown]
# # Get all the method names

# %%
methodNames_list = benchmark_data['Method_Name'].unique().tolist()
#methodNames_list

# %% [markdown]
# # Store the data method wise separately

# %%
methodWiseData = {}
for name in methodNames_list:
    methodWiseData[name] = benchmark_data[(benchmark_data.Method_Name == name)]

# %% [markdown]
# # Save the data method wise to a folder in tsv.gz format

# %%
#for i in names_list:
#    print(d[i])
import os
if not os.path.isdir('newBenchmark_results'):
    os.mkdir('newBenchmark_results')

gb = methodWiseData['AdaBoostClassifier']
gb.to_pickle('newBenchmark_results/AdaBoostClassifier_results.tsv.gz')

# %%
method_data = pd.read_pickle('newBenchmark_results/AdaBoostClassifier-benchmark_results.tsv.gz')
method_data
# Out:
#         Dataset_Name         Method_Name                           Parameters  \
# 1589          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1590          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1591          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1592          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1593          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1594          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1595          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1596          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1597          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1598          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1599          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1600          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1601          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1602          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1603          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1604          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1605          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1606          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1607          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1608          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1609          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1610          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1611          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1612          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1613          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1614          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1615          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1616          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1617          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# 1618          trains  AdaBoostClassifier   learning_rate=0.01,n_estimators=10
# ...              ...                 ...                                  ...
# 2157149       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157150       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157151       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157152       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157153       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157154       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157155       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157156       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157157       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157158       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157159       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157160       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157161       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157162       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157163       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157164       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157165       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157166       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157167       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157168       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157169       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157170       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157171       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157172       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157173       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157174       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157175       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157176       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157177       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
# 2157178       sponge  AdaBoostClassifier  learning_rate=10.0,n_estimators=500
#
#          Test_Score
# 1589           0.50
# 1590           0.50
# 1591           0.50
# 1592           0.50
# 1593           0.50
# 1594           0.50
# 1595           0.50
# 1596           1.00
# 1597           1.00
# 1598           1.00
# 1599           1.00
# 1600           0.00
# 1601           0.50
# 1602           0.50
# 1603           1.00
# 1604           1.00
# 1605           1.00
# 1606           0.50
# 1607           0.50
# 1608           1.00
# 1609           1.00
# 1610           0.50
# 1611           1.00
# 1612           0.50
# 1613           1.00
# 1614           1.00
# 1615           1.00
# 1616           1.00
# 1617           1.00
# 1618           0.50
# ...             ...
# 2157149        0.45
# 2157150        0.05
# 2157151        0.10
# 2157152        0.05
# 2157153        0.05
# 2157154        0.85
# 2157155        0.05
# 2157156        0.05
# 2157157        0.10
# 2157158        0.50
# 2157159        0.80
# 2157160        0.05
# 2157161        0.05
# 2157162        0.05
# 2157163        0.05
# 2157164        0.05
# 2157165        0.05
# 2157166        0.75
# 2157167        0.05
# 2157168        0.90
# 2157169        0.65
# 2157170        0.50
# 2157171        0.05
# 2157172        0.90
# 2157173        0.05
# 2157174        0.80
# 2157175        0.05
# 2157176        0.05
# 2157177        0.60
# 2157178        0.05
#
# [10500 rows x 4 columns]

# %% [markdown]
# # Split the parameters into dfifferent columns;
# # make sure to set the no of coumns according to different methods

# %%
method_param = pd.DataFrame(method_data.Parameters.str.split(',').tolist(),
                                   columns = ['Param1','Param2'])
method_param
# Out:
#                    Param1            Param2
# 0      learning_rate=0.01   n_estimators=10
# 1      learning_rate=0.01   n_estimators=10
# 2      learning_rate=0.01   n_estimators=10
# 3      learning_rate=0.01   n_estimators=10
# 4      learning_rate=0.01   n_estimators=10
# 5      learning_rate=0.01   n_estimators=10
# 6      learning_rate=0.01   n_estimators=10
# 7      learning_rate=0.01   n_estimators=10
# 8      learning_rate=0.01   n_estimators=10
# 9      learning_rate=0.01   n_estimators=10
# 10     learning_rate=0.01   n_estimators=10
# 11     learning_rate=0.01   n_estimators=10
# 12     learning_rate=0.01   n_estimators=10
# 13     learning_rate=0.01   n_estimators=10
# 14     learning_rate=0.01   n_estimators=10
# 15     learning_rate=0.01   n_estimators=10
# 16     learning_rate=0.01   n_estimators=10
# 17     learning_rate=0.01   n_estimators=10
# 18     learning_rate=0.01   n_estimators=10
# 19     learning_rate=0.01   n_estimators=10
# 20     learning_rate=0.01   n_estimators=10
# 21     learning_rate=0.01   n_estimators=10
# 22     learning_rate=0.01   n_estimators=10
# 23     learning_rate=0.01   n_estimators=10
# 24     learning_rate=0.01   n_estimators=10
# 25     learning_rate=0.01   n_estimators=10
# 26     learning_rate=0.01   n_estimators=10
# 27     learning_rate=0.01   n_estimators=10
# 28     learning_rate=0.01   n_estimators=10
# 29     learning_rate=0.01   n_estimators=10
# ...                   ...               ...
# 10470  learning_rate=10.0  n_estimators=500
# 10471  learning_rate=10.0  n_estimators=500
# 10472  learning_rate=10.0  n_estimators=500
# 10473  learning_rate=10.0  n_estimators=500
# 10474  learning_rate=10.0  n_estimators=500
# 10475  learning_rate=10.0  n_estimators=500
# 10476  learning_rate=10.0  n_estimators=500
# 10477  learning_rate=10.0  n_estimators=500
# 10478  learning_rate=10.0  n_estimators=500
# 10479  learning_rate=10.0  n_estimators=500
# 10480  learning_rate=10.0  n_estimators=500
# 10481  learning_rate=10.0  n_estimators=500
# 10482  learning_rate=10.0  n_estimators=500
# 10483  learning_rate=10.0  n_estimators=500
# 10484  learning_rate=10.0  n_estimators=500
# 10485  learning_rate=10.0  n_estimators=500
# 10486  learning_rate=10.0  n_estimators=500
# 10487  learning_rate=10.0  n_estimators=500
# 10488  learning_rate=10.0  n_estimators=500
# 10489  learning_rate=10.0  n_estimators=500
# 10490  learning_rate=10.0  n_estimators=500
# 10491  learning_rate=10.0  n_estimators=500
# 10492  learning_rate=10.0  n_estimators=500
# 10493  learning_rate=10.0  n_estimators=500
# 10494  learning_rate=10.0  n_estimators=500
# 10495  learning_rate=10.0  n_estimators=500
# 10496  learning_rate=10.0  n_estimators=500
# 10497  learning_rate=10.0  n_estimators=500
# 10498  learning_rate=10.0  n_estimators=500
# 10499  learning_rate=10.0  n_estimators=500
#
# [10500 rows x 2 columns]

# %%
method_data1 = method_data.drop('Parameters', 1)   #delete the Parameters column from the original dataframe
idx = method_param.index.get_values()              #get the index of the parameter dataframe  
#idx
method_data2 = method_data1.set_index(idx)         #set the index of method dataframe same as parameter dataframe
#kneighbor_data2
result = pd.concat([method_data2, method_param], axis = 1)    #finally add the parameter columns to get the result (desired format)
#result

# %% [markdown]
# # Save this result in the HPCC_benchmark_results folder

# %%
import os
if not os.path.isdir('HPCC_benchmark_results'):
    os.mkdir('HPCC_benchmark_results')
result.to_pickle('HPCC_benchmark_results/GradientBoostingClassifier-hpcc_results.tsv.gz')

# %%
data = pd.read_pickle('HPCC_benchmark_results/GradientBoostingClassifier-hpcc_results.tsv.gz')
data
# Out:
#                     Dataset_Name                 Method_Name  Test_Score  \
# 0                        heart-c  GradientBoostingClassifier    0.736842
# 1                        heart-c  GradientBoostingClassifier    0.815789
# 2                        heart-c  GradientBoostingClassifier    0.802632
# 3                        heart-c  GradientBoostingClassifier    0.750000
# 4                        heart-c  GradientBoostingClassifier    0.815789
# 5                        heart-c  GradientBoostingClassifier    0.684211
# 6                        heart-c  GradientBoostingClassifier    0.763158
# 7                        heart-c  GradientBoostingClassifier    0.750000
# 8                        heart-c  GradientBoostingClassifier    0.710526
# 9                        heart-c  GradientBoostingClassifier    0.776316
# 10                       heart-c  GradientBoostingClassifier    0.723684
# 11                       heart-c  GradientBoostingClassifier    0.736842
# 12                       heart-c  GradientBoostingClassifier    0.789474
# 13                       heart-c  GradientBoostingClassifier    0.789474
# 14                       heart-c  GradientBoostingClassifier    0.736842
# 15                       heart-c  GradientBoostingClassifier    0.736842
# 16                       heart-c  GradientBoostingClassifier    0.776316
# 17                       heart-c  GradientBoostingClassifier    0.763158
# 18                       heart-c  GradientBoostingClassifier    0.802632
# 19                       heart-c  GradientBoostingClassifier    0.815789
# 20                       heart-c  GradientBoostingClassifier    0.828947
# 21                       heart-c  GradientBoostingClassifier    0.736842
# 22                       heart-c  GradientBoostingClassifier    0.736842
# 23                       heart-c  GradientBoostingClassifier    0.750000
# 24                       heart-c  GradientBoostingClassifier    0.789474
# 25                       heart-c  GradientBoostingClassifier    0.815789
# 26                       heart-c  GradientBoostingClassifier    0.697368
# 27                       heart-c  GradientBoostingClassifier    0.842105
# 28                       heart-c  GradientBoostingClassifier    0.776316
# 29       shuttle-landing-control  GradientBoostingClassifier    0.750000
# ...                          ...                         ...         ...
# 1527479  shuttle-landing-control  GradientBoostingClassifier    0.500000
# 1527480  shuttle-landing-control  GradientBoostingClassifier    0.750000
# 1527481  shuttle-landing-control  GradientBoostingClassifier    0.750000
# 1527482  shuttle-landing-control  GradientBoostingClassifier    0.500000
# 1527483  shuttle-landing-control  GradientBoostingClassifier    0.750000
# 1527484  shuttle-landing-control  GradientBoostingClassifier    0.750000
# 1527485  shuttle-landing-control  GradientBoostingClassifier    0.750000
# 1527486  shuttle-landing-control  GradientBoostingClassifier    0.250000
# 1527487  shuttle-landing-control  GradientBoostingClassifier    0.750000
# 1527488  shuttle-landing-control  GradientBoostingClassifier    0.750000
# 1527489  shuttle-landing-control  GradientBoostingClassifier    1.000000
# 1527490  shuttle-landing-control  GradientBoostingClassifier    0.500000
# 1527491  shuttle-landing-control  GradientBoostingClassifier    1.000000
# 1527492  shuttle-landing-control  GradientBoostingClassifier    0.750000
# 1527493  shuttle-landing-control  GradientBoostingClassifier    0.750000
# 1527494  shuttle-landing-control  GradientBoostingClassifier    0.750000
# 1527495  shuttle-landing-control  GradientBoostingClassifier    0.750000
# 1527496  shuttle-landing-control  GradientBoostingClassifier    0.750000
# 1527497  shuttle-landing-control  GradientBoostingClassifier    0.500000
# 1527498  shuttle-landing-control  GradientBoostingClassifier    0.500000
# 1527499  shuttle-landing-control  GradientBoostingClassifier    0.500000
# 1527500  shuttle-landing-control  GradientBoostingClassifier    0.500000
# 1527501  shuttle-landing-control  GradientBoostingClassifier    0.750000
# 1527502  shuttle-landing-control  GradientBoostingClassifier    0.750000
# 1527503  shuttle-landing-control  GradientBoostingClassifier    1.000000
# 1527504  shuttle-landing-control  GradientBoostingClassifier    0.500000
# 1527505  shuttle-landing-control  GradientBoostingClassifier    0.500000
# 1527506  shuttle-landing-control  GradientBoostingClassifier    0.500000
# 1527507  shuttle-landing-control  GradientBoostingClassifier    0.250000
# 1527508  shuttle-landing-control  GradientBoostingClassifier    0.500000
#
#                    Param1              Param2             Param3       Param4  \
# 0        loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 1        loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 2        loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 3        loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 4        loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 5        loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 6        loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 7        loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 8        loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 9        loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 10       loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 11       loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 12       loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 13       loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 14       loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 15       loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 16       loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 17       loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 18       loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 19       loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 20       loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 21       loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 22       loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 23       loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 24       loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 25       loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 26       loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 27       loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 28       loss=exponential  learning_rate=10.0   n_estimators=100  max_depth=3
# 29          loss=deviance  learning_rate=50.0    n_estimators=10  max_depth=2
# ...                   ...                 ...                ...          ...
# 1527479     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527480     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527481     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527482     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527483     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527484     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527485     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527486     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527487     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527488     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527489     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527490     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527491     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527492     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527493     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527494     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527495     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527496     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527497     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527498     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527499     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527500     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527501     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527502     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527503     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527504     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527505     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527506     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527507     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
# 1527508     loss=deviance   learning_rate=0.5  n_estimators=1000  max_depth=2
#
#                     Param5           Param6
# 0        max_features=sqrt  warm_start=True
# 1        max_features=sqrt  warm_start=True
# 2        max_features=sqrt  warm_start=True
# 3        max_features=sqrt  warm_start=True
# 4        max_features=sqrt  warm_start=True
# 5        max_features=sqrt  warm_start=True
# 6        max_features=sqrt  warm_start=True
# 7        max_features=sqrt  warm_start=True
# 8        max_features=sqrt  warm_start=True
# 9        max_features=sqrt  warm_start=True
# 10       max_features=sqrt  warm_start=True
# 11       max_features=sqrt  warm_start=True
# 12       max_features=sqrt  warm_start=True
# 13       max_features=sqrt  warm_start=True
# 14       max_features=sqrt  warm_start=True
# 15       max_features=sqrt  warm_start=True
# 16       max_features=sqrt  warm_start=True
# 17       max_features=sqrt  warm_start=True
# 18       max_features=sqrt  warm_start=True
# 19       max_features=sqrt  warm_start=True
# 20       max_features=sqrt  warm_start=True
# 21       max_features=sqrt  warm_start=True
# 22       max_features=sqrt  warm_start=True
# 23       max_features=sqrt  warm_start=True
# 24       max_features=sqrt  warm_start=True
# 25       max_features=sqrt  warm_start=True
# 26       max_features=sqrt  warm_start=True
# 27       max_features=sqrt  warm_start=True
# 28       max_features=sqrt  warm_start=True
# 29       max_features=log2  warm_start=True
# ...                    ...              ...
# 1527479  max_features=0.75  warm_start=True
# 1527480  max_features=0.75  warm_start=True
# 1527481  max_features=0.75  warm_start=True
# 1527482  max_features=0.75  warm_start=True
# 1527483  max_features=0.75  warm_start=True
# 1527484  max_features=0.75  warm_start=True
# 1527485  max_features=0.75  warm_start=True
# 1527486  max_features=0.75  warm_start=True
# 1527487  max_features=0.75  warm_start=True
# 1527488  max_features=0.75  warm_start=True
# 1527489  max_features=0.75  warm_start=True
# 1527490  max_features=0.75  warm_start=True
# 1527491  max_features=0.75  warm_start=True
# 1527492  max_features=0.75  warm_start=True
# 1527493  max_features=0.75  warm_start=True
# 1527494  max_features=0.75  warm_start=True
# 1527495  max_features=0.75  warm_start=True
# 1527496  max_features=0.75  warm_start=True
# 1527497  max_features=0.75  warm_start=True
# 1527498  max_features=0.75  warm_start=True
# 1527499  max_features=0.75  warm_start=True
# 1527500  max_features=0.75  warm_start=True
# 1527501  max_features=0.75  warm_start=True
# 1527502  max_features=0.75  warm_start=True
# 1527503  max_features=0.75  warm_start=True
# 1527504  max_features=0.75  warm_start=True
# 1527505  max_features=0.75  warm_start=True
# 1527506  max_features=0.75  warm_start=True
# 1527507  max_features=0.75  warm_start=True
# 1527508  max_features=0.75  warm_start=True
#
# [1527509 rows x 9 columns]
