# %% [markdown]
# # Import Pandas and Rename the Columns

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

benchmark_data = pd.read_csv('sklearn-benchmark-data.tsv.gz', sep='\t')
benchmark_data.head()

# %%
benchmark_data.rename(columns={'tae':'Dataset_Name',
                               'LinearSVC':'Method_Name',
                               'C=0.01,loss=hinge,penalty=l2,dual=True,tol=0.1':'Parameters',
                               '0.421052631579':'Test_Score'},inplace=True)
benchmark_data.head()
# Out:
#   Dataset_Name Method_Name                                      Parameters  \
# 0          tae   LinearSVC  C=0.01,loss=hinge,penalty=l2,dual=True,tol=0.1
# 1          tae   LinearSVC  C=0.01,loss=hinge,penalty=l2,dual=True,tol=0.1
# 2          tae   LinearSVC  C=0.01,loss=hinge,penalty=l2,dual=True,tol=0.1
# 3          tae   LinearSVC  C=0.01,loss=hinge,penalty=l2,dual=True,tol=0.1
# 4          tae   LinearSVC  C=0.01,loss=hinge,penalty=l2,dual=True,tol=0.1
#
#    Test_Score
# 0    0.578947
# 1    0.500000
# 2    0.473684
# 3    0.500000
# 4    0.578947

# %% [markdown]
# # Preliminary Analysis

# %%
benchmark_data.describe()

# %%
benchmark_data.shape

# %% [markdown]
# # List all the methods so as to divide the dataset into multiple dataframes

# %%
names_list=benchmark_data['Dataset_Name'].unique().tolist()
methods_list=benchmark_data['Method_Name'].unique().tolist()
names_list
methods_list

# %%
len(methods_list)

# %%
#split the dataframe into multiple dataframes by the method name
methods_list=benchmark_data['Method_Name'].unique().tolist()
MethodWiseData={}
for method_name in methods_list:
    MethodWiseData[method_name] = benchmark_data[benchmark_data.Method_Name==method_name]

# %% [markdown]
# # Make a folder to save the file

# %%
# make a folder and save a file
import os
if not os.path.isdir('Benchmark_Results_18thApril2016'):
    os.mkdir('Benchmark_Results_18thApril2016') 

MethodWiseData['LogisticRegression'].to_pickle('Benchmark_Results_18thApril2016/LogisticRegression.tsv.gz')

# %%
# Read the file
Method_Type = pd.read_pickle('Benchmark_Results_18thApril2016/LogisticRegression.tsv.gz')
print (Method_Type)
Method_Type.head()
# Out:
#          Dataset_Name         Method_Name          Parameters  Test_Score
# 342419           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342420           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342421           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342422           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342423           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342424           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342425           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342426           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342427           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342428           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342429           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342430           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342431           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342432           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342433           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342434           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342435           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342436           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342437           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342438           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342439           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342440           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342441           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342442           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342443           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342444           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342445           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342446           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342447           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# 342448           wine  LogisticRegression   C=0.01,penalty=l1    0.333333
# ...               ...                 ...                 ...         ...
# 27327330  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.963477
# 27327331  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.956172
# 27327332  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.959094
# 27327333  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.956172
# 27327334  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.962016
# 27327335  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.950329
# 27327336  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.956172
# 27327337  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.961286
# 27327338  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.955442
# 27327339  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.953981
# 27327340  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.964938
# 27327341  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.961286
# 27327342  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.957633
# 27327343  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.966399
# 27327344  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.962016
# 27327345  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.953251
# 27327346  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.959825
# 27327347  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.963477
# 27327348  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.959094
# 27327349  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.951790
# 27327350  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.966399
# 27327351  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.956172
# 27327352  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.962747
# 27327353  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.967129
# 27327354  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.960555
# 27327355  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.950329
# 27327356  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.959094
# 27327357  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.960555
# 27327358  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.955442
# 27327359  page-blocks  LogisticRegression  C=100.0,penalty=l2    0.957633
#
# [72240 rows x 4 columns]
#        Dataset_Name         Method_Name         Parameters  Test_Score
# 342419         wine  LogisticRegression  C=0.01,penalty=l1    0.333333
# 342420         wine  LogisticRegression  C=0.01,penalty=l1    0.333333
# 342421         wine  LogisticRegression  C=0.01,penalty=l1    0.333333
# 342422         wine  LogisticRegression  C=0.01,penalty=l1    0.333333
# 342423         wine  LogisticRegression  C=0.01,penalty=l1    0.333333

# %% [markdown]
# Note: To run the code for all parameters, it is required to change in the above section the method name appropriately. Also below the number of parameters have to be inputted approprietly and the parameter name has to be changed as well to achieve the data cleaning for all methods.

# %% [markdown]
# # Split the Parameters columns (Every method has different number of parameters)

# %%
Param_Split = pd.DataFrame(Method_Type.Parameters.str.split(',').tolist(),
                                   columns = ['Param1','Param2'])
#Param_Split

# %%
Method_Type1 = Method_Type.drop('Parameters', 1)    #delete the Parameters column from the original dataframe
index = Param_Split.index.get_values()              #get the index of the parameter dataframe  
Method_Type2 = Method_Type1.set_index(index)          #set the index of method dataframe same as parameter dataframe
result = pd.concat([Method_Type2, Param_Split], axis = 1)    #finally add the parameter columns to get the result (desired format)
#result

# %%
# Split the Parameter Column to process it further and have only numeric values in it
data_split1 = pd.DataFrame(result.Param1.str.split('=').tolist(),
                                   columns = ['Param_Name','C'])
data_split2 = pd.DataFrame(result.Param2.str.split('=').tolist(),
                                   columns = ['Param_Name','penalty'])
#data_split3 = pd.DataFrame(result.Param3.str.split('=').tolist(),
#                                   columns = ['Param_Name','criterion'])
#data_split4 = pd.DataFrame(result.Param4.str.split('=').tolist(),
#                                   columns = ['Param_Name','kernel'])
#data_split5 = pd.DataFrame(result.Param5.str.split('=').tolist(),
#                                   columns = ['Param_Name','degree'])
#data_split6 = pd.DataFrame(result.Param5.str.split('=').tolist(),
#                                   columns = ['Param_Name','warm_start'])

# Delete the Parameters column from the original dataframe
method_data1 = result.drop('Param1',1)  
method_data1 = method_data1.drop('Param2',1)
#method_data1 = method_data1.drop('Param3',1)
#method_data1 = method_data1.drop('Param4',1)
#method_data1 = method_data1.drop('Param5',1)
#method_data1 = method_data1.drop('Param6',1)

data_split1 = data_split1.drop('Param_Name',1)
data_split2 = data_split2.drop('Param_Name',1)
#data_split3 = data_split3.drop('Param_Name',1)
#data_split4 = data_split4.drop('Param_Name',1)
#data_split5 = data_split5.drop('Param_Name',1)
#data_split6 = data_split6.drop('Param_Name',1)

idx = data_split1.index.get_values()               #get the index of the parameter dataframe  
method_data2 = method_data1.set_index(idx)         #set the index of method dataframe same as parameter dataframe
cleaned_data = pd.concat([method_data2, data_split1, data_split2], axis = 1)
#finally add the parameter columns to get the result (desired format)

# You must cast the data as a float type -- it was parsed into a string type
#cleaned_data['n_estimators'] = cleaned_data['n_estimators'].astype(float)
#cleaned_data['learning_rate'] = cleaned_data['learning_rate'].astype(float)
#cleaned_data['warm_start'] = cleaned_data['warm_start'].astype(float)
#cleaned_data['criterion'] = cleaned_data['criterion'].astype(float)
#cleaned_data['warm_start'] = cleaned_data['warm_start'].astype(float)

#cleaned_data

# %% [markdown]
# # Save this file of a method and parameters organized in columns

# %%
import os
if not os.path.isdir('Cleaned_Method_Wise_Data_18thApril2016'):
    os.mkdir('Cleaned_Method_Wise_Data_18thApril2016')
cleaned_data.to_pickle('Cleaned_Method_Wise_Data_18thApril2016/LogisticRegression_cleaned.tsv.gz')

# %%
# Read the file
Cleaned_Data = pd.read_pickle('Cleaned_Method_Wise_Data_18thApril2016/LogisticRegression_cleaned.tsv.gz')
Cleaned_Data
# Out:
#       Dataset_Name         Method_Name  Test_Score      C penalty
# 0             wine  LogisticRegression    0.333333   0.01      l1
# 1             wine  LogisticRegression    0.333333   0.01      l1
# 2             wine  LogisticRegression    0.333333   0.01      l1
# 3             wine  LogisticRegression    0.333333   0.01      l1
# 4             wine  LogisticRegression    0.333333   0.01      l1
# 5             wine  LogisticRegression    0.333333   0.01      l1
# 6             wine  LogisticRegression    0.333333   0.01      l1
# 7             wine  LogisticRegression    0.333333   0.01      l1
# 8             wine  LogisticRegression    0.333333   0.01      l1
# 9             wine  LogisticRegression    0.333333   0.01      l1
# 10            wine  LogisticRegression    0.333333   0.01      l1
# 11            wine  LogisticRegression    0.333333   0.01      l1
# 12            wine  LogisticRegression    0.333333   0.01      l1
# 13            wine  LogisticRegression    0.333333   0.01      l1
# 14            wine  LogisticRegression    0.333333   0.01      l1
# 15            wine  LogisticRegression    0.333333   0.01      l1
# 16            wine  LogisticRegression    0.333333   0.01      l1
# 17            wine  LogisticRegression    0.333333   0.01      l1
# 18            wine  LogisticRegression    0.333333   0.01      l1
# 19            wine  LogisticRegression    0.333333   0.01      l1
# 20            wine  LogisticRegression    0.333333   0.01      l1
# 21            wine  LogisticRegression    0.333333   0.01      l1
# 22            wine  LogisticRegression    0.333333   0.01      l1
# 23            wine  LogisticRegression    0.333333   0.01      l1
# 24            wine  LogisticRegression    0.333333   0.01      l1
# 25            wine  LogisticRegression    0.333333   0.01      l1
# 26            wine  LogisticRegression    0.333333   0.01      l1
# 27            wine  LogisticRegression    0.333333   0.01      l1
# 28            wine  LogisticRegression    0.333333   0.01      l1
# 29            wine  LogisticRegression    0.333333   0.01      l1
# ...            ...                 ...         ...    ...     ...
# 72210  page-blocks  LogisticRegression    0.963477  100.0      l2
# 72211  page-blocks  LogisticRegression    0.956172  100.0      l2
# 72212  page-blocks  LogisticRegression    0.959094  100.0      l2
# 72213  page-blocks  LogisticRegression    0.956172  100.0      l2
# 72214  page-blocks  LogisticRegression    0.962016  100.0      l2
# 72215  page-blocks  LogisticRegression    0.950329  100.0      l2
# 72216  page-blocks  LogisticRegression    0.956172  100.0      l2
# 72217  page-blocks  LogisticRegression    0.961286  100.0      l2
# 72218  page-blocks  LogisticRegression    0.955442  100.0      l2
# 72219  page-blocks  LogisticRegression    0.953981  100.0      l2
# 72220  page-blocks  LogisticRegression    0.964938  100.0      l2
# 72221  page-blocks  LogisticRegression    0.961286  100.0      l2
# 72222  page-blocks  LogisticRegression    0.957633  100.0      l2
# 72223  page-blocks  LogisticRegression    0.966399  100.0      l2
# 72224  page-blocks  LogisticRegression    0.962016  100.0      l2
# 72225  page-blocks  LogisticRegression    0.953251  100.0      l2
# 72226  page-blocks  LogisticRegression    0.959825  100.0      l2
# 72227  page-blocks  LogisticRegression    0.963477  100.0      l2
# 72228  page-blocks  LogisticRegression    0.959094  100.0      l2
# 72229  page-blocks  LogisticRegression    0.951790  100.0      l2
# 72230  page-blocks  LogisticRegression    0.966399  100.0      l2
# 72231  page-blocks  LogisticRegression    0.956172  100.0      l2
# 72232  page-blocks  LogisticRegression    0.962747  100.0      l2
# 72233  page-blocks  LogisticRegression    0.967129  100.0      l2
# 72234  page-blocks  LogisticRegression    0.960555  100.0      l2
# 72235  page-blocks  LogisticRegression    0.950329  100.0      l2
# 72236  page-blocks  LogisticRegression    0.959094  100.0      l2
# 72237  page-blocks  LogisticRegression    0.960555  100.0      l2
# 72238  page-blocks  LogisticRegression    0.955442  100.0      l2
# 72239  page-blocks  LogisticRegression    0.957633  100.0      l2
#
# [72240 rows x 5 columns]
