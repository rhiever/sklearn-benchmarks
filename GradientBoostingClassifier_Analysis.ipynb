# %%
import pandas as pd

benchmark_data = pd.read_csv('sklearn-benchmark-data.tsv.gz', sep='\t')
benchmark_data.head()
benchmark_data.rename(columns={'heart-c':'Dataset_Name',
                               'GradientBoostingClassifier':'Method_Name',
                               'loss=exponential,learning_rate=10.0,n_estimators=100,max_depth=3,max_features=sqrt,warm_start=True':'Prameters',
                               '0.723684210526':'Test_Score'},inplace=True)
benchmark_data
# Out:
#    heart-c  GradientBoostingClassifier  \
# 0  heart-c  GradientBoostingClassifier
# 1  heart-c  GradientBoostingClassifier
# 2  heart-c  GradientBoostingClassifier
# 3  heart-c  GradientBoostingClassifier
# 4  heart-c  GradientBoostingClassifier
#
#   loss=exponential,learning_rate=10.0,n_estimators=100,max_depth=3,max_features=sqrt,warm_start=True  \
# 0  loss=exponential,learning_rate=10.0,n_estimato...
# 1  loss=exponential,learning_rate=10.0,n_estimato...
# 2  loss=exponential,learning_rate=10.0,n_estimato...
# 3  loss=exponential,learning_rate=10.0,n_estimato...
# 4  loss=exponential,learning_rate=10.0,n_estimato...
#
#    0.723684210526
# 0        0.736842
# 1        0.815789
# 2        0.802632
# 3        0.750000
# 4        0.815789

# %%
benchmark_data.rename(columns={'GradientBoostingClassifier':'Method_Name',
                               'loss=exponential,learning_rate=10.0,n_estimators=100,max_depth=3,max_features=sqrt,warm_start=True':'Prameters',
                               '0.723684210526':'Test_Score'},inplace=True)
benchmark_data
# Out:
#                      DataSetName                 Method_Name  \
# 0                        heart-c  GradientBoostingClassifier
# 1                        heart-c  GradientBoostingClassifier
# 2                        heart-c  GradientBoostingClassifier
# 3                        heart-c  GradientBoostingClassifier
# 4                        heart-c  GradientBoostingClassifier
# 5                        heart-c  GradientBoostingClassifier
# 6                        heart-c  GradientBoostingClassifier
# 7                        heart-c  GradientBoostingClassifier
# 8                        heart-c  GradientBoostingClassifier
# 9                        heart-c  GradientBoostingClassifier
# 10                       heart-c  GradientBoostingClassifier
# 11                       heart-c  GradientBoostingClassifier
# 12                       heart-c  GradientBoostingClassifier
# 13                       heart-c  GradientBoostingClassifier
# ...
