# %%
from glob import glob
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import StratifiedShuffleSplit
import itertools
from collections import defaultdict

all_model_scores = defaultdict(list)

# For every data set in the data repository...
for dataset in glob('data/ecoli.csv.gz'):
    # Read the data set into memory
    input_data = pd.read_csv(dataset, compression='gzip')
    
    for dataset_repeat in range(1, 31):
        # Divide the data set into a training and testing sets, each time with a different RNG seed
        training_indices, testing_indices = next(iter(StratifiedShuffleSplit(input_data['class'].values,
                                                                             n_iter=1,
                                                                             train_size=0.75,
                                                                             test_size=0.25,
                                                                             random_state=dataset_repeat)))
        
        training_features = input_data.loc[training_indices].drop('class', axis=1).values
        training_classes = input_data.loc[training_indices, 'class'].values

        testing_features = input_data.loc[testing_indices].drop('class', axis=1).values
        testing_classes = input_data.loc[testing_indices, 'class'].values
        
        # These are parameters listed in the project document
        C_list = [0.01, 0.1, 0.5, 1.0, 10.0, 50.0, 100.0]
        penalty_list = ['l1', 'l2']
        # For every DecisionTreeClassifier parameter combination...
        for (C, penalty) in itertools.product(C_list, penalty_list):
            # Create and fit the model on the training data
            clf = LogisticRegression(C = C, penalty = penalty)
            clf.fit(training_features, training_classes)
            
            # Store the model's score with the key (name of data set, model, model parameters)
            all_model_scores[(dataset,
                              'LogisticRegression',
                              (C, penalty))].append(clf.score(testing_features, testing_classes))

# %%
import os
import gzip

if not os.path.isdir('benchmark_results'):
    os.mkdir('benchmark_results')

with gzip.open('benchmark_results/LogisticRegression_eoli-benchmarks.tsv.gz', 'wb') as out_file:
    header_text = '\t'.join(['dataset',
                              'model',
                              'parameters',
                              'testing_score']) + '\n'
    out_file.write(header_text.encode('UTF-8'))
    
    for (dataset, model, params) in all_model_scores:
        param_string = ''
        param_string += 'C={},'.format(params[0])
        param_string += 'penalty={},'.format(params[1])
        
        for testing_score in all_model_scores[(dataset, model, params)]:
            out_text = '\t'.join([dataset[5:-7],
                                  model,
                                  param_string,
                                  str(testing_score)]) + '\n'
            out_file.write(out_text.encode('UTF-8'))

# %%
import pandas as pd

pd.read_csv('benchmark_results/LogisticRegression_eoli-benchmarks.tsv.gz', compression='gzip', sep='\t')
# Out:
#     dataset               model          parameters  testing_score
# 0     ecoli  LogisticRegression  C=50.0,penalty=l2,       0.926829
# 1     ecoli  LogisticRegression  C=50.0,penalty=l2,       0.878049
# 2     ecoli  LogisticRegression  C=50.0,penalty=l2,       0.914634
# 3     ecoli  LogisticRegression  C=50.0,penalty=l2,       0.865854
# 4     ecoli  LogisticRegression  C=50.0,penalty=l2,       0.853659
# 5     ecoli  LogisticRegression  C=50.0,penalty=l2,       0.853659
# 6     ecoli  LogisticRegression  C=50.0,penalty=l2,       0.841463
# 7     ecoli  LogisticRegression  C=50.0,penalty=l2,       0.853659
# 8     ecoli  LogisticRegression  C=50.0,penalty=l2,       0.914634
# 9     ecoli  LogisticRegression  C=50.0,penalty=l2,       0.865854
# 10    ecoli  LogisticRegression  C=50.0,penalty=l2,       0.878049
# 11    ecoli  LogisticRegression  C=50.0,penalty=l2,       0.853659
# 12    ecoli  LogisticRegression  C=50.0,penalty=l2,       0.865854
# 13    ecoli  LogisticRegression  C=50.0,penalty=l2,       0.890244
# 14    ecoli  LogisticRegression  C=50.0,penalty=l2,       0.829268
# 15    ecoli  LogisticRegression  C=50.0,penalty=l2,       0.853659
# 16    ecoli  LogisticRegression  C=50.0,penalty=l2,       0.878049
# 17    ecoli  LogisticRegression  C=50.0,penalty=l2,       0.902439
# 18    ecoli  LogisticRegression  C=50.0,penalty=l2,       0.878049
# 19    ecoli  LogisticRegression  C=50.0,penalty=l2,       0.890244
# 20    ecoli  LogisticRegression  C=50.0,penalty=l2,       0.853659
# 21    ecoli  LogisticRegression  C=50.0,penalty=l2,       0.853659
# 22    ecoli  LogisticRegression  C=50.0,penalty=l2,       0.878049
# 23    ecoli  LogisticRegression  C=50.0,penalty=l2,       0.853659
# 24    ecoli  LogisticRegression  C=50.0,penalty=l2,       0.890244
# 25    ecoli  LogisticRegression  C=50.0,penalty=l2,       0.865854
# 26    ecoli  LogisticRegression  C=50.0,penalty=l2,       0.914634
# 27    ecoli  LogisticRegression  C=50.0,penalty=l2,       0.853659
# 28    ecoli  LogisticRegression  C=50.0,penalty=l2,       0.878049
# 29    ecoli  LogisticRegression  C=50.0,penalty=l2,       0.878049
# ..      ...                 ...                 ...            ...
# 390   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 391   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 392   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 393   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 394   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 395   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 396   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 397   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 398   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 399   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 400   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 401   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 402   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 403   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 404   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 405   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 406   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 407   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 408   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 409   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 410   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 411   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 412   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 413   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 414   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 415   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 416   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 417   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 418   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
# 419   ecoli  LogisticRegression  C=0.01,penalty=l1,       0.439024
#
# [420 rows x 4 columns]
