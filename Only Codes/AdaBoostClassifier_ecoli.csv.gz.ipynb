# %%
from glob import glob
import pandas as pd
from sklearn.ensemble import AdaBoostClassifier
from sklearn.cross_validation import StratifiedShuffleSplit
import itertools
from collections import defaultdict

all_model_scores = defaultdict(list)

# For every data set in the data repository...
for dataset in glob('data/ecoli.csv.gz'):
    # Read the data set into memory
    input_data = pd.read_csv(dataset, compression='gzip')
    
    for dataset_repeat in range(1, 31):
        # Divide the data set into a training and testing sets, each time with a different RNG seed
        training_indices, testing_indices = next(iter(StratifiedShuffleSplit(input_data['class'].values,
                                                                             n_iter=1,
                                                                             train_size=0.75,
                                                                             test_size=0.25,
                                                                             random_state=dataset_repeat)))
        
        training_features = input_data.loc[training_indices].drop('class', axis=1).values
        training_classes = input_data.loc[training_indices, 'class'].values

        testing_features = input_data.loc[testing_indices].drop('class', axis=1).values
        testing_classes = input_data.loc[testing_indices, 'class'].values
        
        # These are parameters listed in the project document
        learning_rate_list = [0.01, 0.1, 0.5, 1.0, 10.0, 50.0, 100.0]
        n_estimators_list = [10, 50, 100, 500, 1000]
        # For every DecisionTreeClassifier parameter combination...
        for (learning_rate, n_estimators) in itertools.product(learning_rate_list, n_estimators_list):
            # Create and fit the model on the training data
            clf = AdaBoostClassifier(learning_rate = learning_rate, n_estimators = n_estimators)
            clf.fit(training_features, training_classes)
            
            # Store the model's score with the key (name of data set, model, model parameters)
            all_model_scores[(dataset,
                              'AdaBoostClassifier',
                              (learning_rate, n_estimators))].append(clf.score(testing_features,
                                                                                      testing_classes))

# %%
import os
import gzip

if not os.path.isdir('benchmark_results'):
    os.mkdir('benchmark_results')

with gzip.open('benchmark_results/AdaBoostClassifier_eoli-benchmarks.tsv.gz', 'wb') as out_file:
    header_text = '\t'.join(['dataset',
                              'model',
                              'parameters',
                              'testing_score']) + '\n'
    out_file.write(header_text.encode('UTF-8'))
    
    for (dataset, model, params) in all_model_scores:
        param_string = ''
        param_string += 'learning_rate={},'.format(params[0])
        param_string += 'n_estimators={},'.format(params[1])
        
        for testing_score in all_model_scores[(dataset, model, params)]:
            out_text = '\t'.join([dataset[5:-7],
                                  model,
                                  param_string,
                                  str(testing_score)]) + '\n'
            out_file.write(out_text.encode('UTF-8'))

# %%
import pandas as pd

pd.read_csv('benchmark_results/AdaBoostClassifier_eoli-benchmarks.tsv.gz', compression='gzip', sep='\t')
# Out:
#      dataset               model                             parameters  \
# 0      ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 1      ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 2      ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 3      ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 4      ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 5      ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 6      ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 7      ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 8      ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 9      ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 10     ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 11     ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 12     ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 13     ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 14     ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 15     ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 16     ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 17     ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 18     ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 19     ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 20     ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 21     ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 22     ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 23     ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 24     ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 25     ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 26     ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 27     ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 28     ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# 29     ecoli  AdaBoostClassifier  learning_rate=100.0,n_estimators=500,
# ...      ...                 ...                                    ...
# 1020   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1021   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1022   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1023   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1024   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1025   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1026   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1027   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1028   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1029   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1030   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1031   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1032   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1033   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1034   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1035   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1036   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1037   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1038   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1039   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1040   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1041   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1042   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1043   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1044   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1045   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1046   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1047   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1048   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
# 1049   ecoli  AdaBoostClassifier    learning_rate=0.5,n_estimators=500,
#
#       testing_score
# 0          0.439024
# 1          0.439024
# 2          0.439024
# 3          0.439024
# 4          0.439024
# 5          0.439024
# 6          0.439024
# 7          0.439024
# 8          0.439024
# 9          0.439024
# 10         0.439024
# 11         0.439024
# 12         0.439024
# 13         0.439024
# 14         0.439024
# 15         0.439024
# 16         0.439024
# 17         0.439024
# 18         0.439024
# 19         0.439024
# 20         0.439024
# 21         0.439024
# 22         0.439024
# 23         0.439024
# 24         0.439024
# 25         0.439024
# 26         0.439024
# 27         0.439024
# 28         0.439024
# 29         0.439024
# ...             ...
# 1020       0.853659
# 1021       0.780488
# 1022       0.768293
# 1023       0.841463
# 1024       0.878049
# 1025       0.817073
# 1026       0.841463
# 1027       0.853659
# 1028       0.865854
# 1029       0.914634
# 1030       0.792683
# 1031       0.829268
# 1032       0.817073
# 1033       0.804878
# 1034       0.829268
# 1035       0.780488
# 1036       0.780488
# 1037       0.817073
# 1038       0.780488
# 1039       0.890244
# 1040       0.768293
# 1041       0.829268
# 1042       0.853659
# 1043       0.719512
# 1044       0.841463
# 1045       0.792683
# 1046       0.829268
# 1047       0.780488
# 1048       0.829268
# 1049       0.792683
#
# [1050 rows x 4 columns]
