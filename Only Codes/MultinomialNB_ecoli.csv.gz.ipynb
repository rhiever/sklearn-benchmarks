# %%
from glob import glob
import pandas as pd
from sklearn.naive_bayes import MultinomialNB
from sklearn.cross_validation import StratifiedShuffleSplit
import itertools
from collections import defaultdict

all_model_scores = defaultdict(list)

# For every data set in the data repository...
for dataset in glob('data/ecoli.csv.gz'):
    # Read the data set into memory
    input_data = pd.read_csv(dataset, compression='gzip')
    
    for dataset_repeat in range(1, 31):
        # Divide the data set into a training and testing sets, each time with a different RNG seed
        training_indices, testing_indices = next(iter(StratifiedShuffleSplit(input_data['class'].values,
                                                                             n_iter=1,
                                                                             train_size=0.75,
                                                                             test_size=0.25,
                                                                             random_state=dataset_repeat)))
        
        training_features = input_data.loc[training_indices].drop('class', axis=1).values
        training_classes = input_data.loc[training_indices, 'class'].values

        testing_features = input_data.loc[testing_indices].drop('class', axis=1).values
        testing_classes = input_data.loc[testing_indices, 'class'].values
        
        # These are parameters listed in the project document
        alpha_list = [0.0, 0.1, 0.25, 0.5, 0.75, 1.0]
        fit_prior_list = [True, False]
        # For every DecisionTreeClassifier parameter combination...
        for (alpha, fit_prior) in itertools.product(alpha_list, fit_prior_list):
            # Create and fit the model on the training data
            clf = MultinomialNB(alpha = alpha, fit_prior = fit_prior)
            clf.fit(training_features, training_classes)
            
            # Store the model's score with the key (name of data set, model, model parameters)
            all_model_scores[(dataset,
                              'MultinomialNB',
                              (alpha, fit_prior))].append(clf.score(testing_features, testing_classes))

# %%
import os
import gzip

if not os.path.isdir('benchmark_results'):
    os.mkdir('benchmark_results')

with gzip.open('benchmark_results/MultinomialNB_eoli-benchmarks.tsv.gz', 'wb') as out_file:
    header_text = '\t'.join(['dataset',
                              'model',
                              'parameters',
                              'testing_score']) + '\n'
    out_file.write(header_text.encode('UTF-8'))
    
    for (dataset, model, params) in all_model_scores:
        param_string = ''
        param_string += 'alpha={},'.format(params[0])
        param_string += 'fit_prior={},'.format(params[1])
        
        for testing_score in all_model_scores[(dataset, model, params)]:
            out_text = '\t'.join([dataset[5:-7],
                                  model,
                                  param_string,
                                  str(testing_score)]) + '\n'
            out_file.write(out_text.encode('UTF-8'))

# %%
import pandas as pd

pd.read_csv('benchmark_results/MultinomialNB_eoli-benchmarks.tsv.gz', compression='gzip', sep='\t')
# Out:
#     dataset          model                   parameters  testing_score
# 0     ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 1     ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 2     ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 3     ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 4     ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 5     ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 6     ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 7     ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 8     ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 9     ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 10    ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 11    ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 12    ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 13    ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 14    ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 15    ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 16    ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 17    ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 18    ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 19    ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 20    ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 21    ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 22    ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 23    ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 24    ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 25    ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 26    ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 27    ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 28    ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# 29    ecoli  MultinomialNB    alpha=0.1,fit_prior=True,       0.439024
# ..      ...            ...                          ...            ...
# 330   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.768293
# 331   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.792683
# 332   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.804878
# 333   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.768293
# 334   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.829268
# 335   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.804878
# 336   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.792683
# 337   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.853659
# 338   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.817073
# 339   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.817073
# 340   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.804878
# 341   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.780488
# 342   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.804878
# 343   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.817073
# 344   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.792683
# 345   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.756098
# 346   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.792683
# 347   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.804878
# 348   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.817073
# 349   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.878049
# 350   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.780488
# 351   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.841463
# 352   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.829268
# 353   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.731707
# 354   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.829268
# 355   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.792683
# 356   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.817073
# 357   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.768293
# 358   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.804878
# 359   ecoli  MultinomialNB  alpha=0.75,fit_prior=False,       0.768293
#
# [360 rows x 4 columns]
