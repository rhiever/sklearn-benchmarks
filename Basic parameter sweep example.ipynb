# %% [markdown]
# This is a basic template for the parameter sweeps you will be performing with scikit-learn.
#
# We will need to add more data sets to the `data` directory. Also, loops like this will need to be created for all models listed in the project document. Make a separate notebook for each model.

# %%
from glob import glob
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.cross_validation import StratifiedShuffleSplit
import itertools
from collections import defaultdict

all_model_scores = defaultdict(list)

# For every data set in the data repository...
for dataset in glob('data/glass.csv.gz'):
    # Read the data set into memory
    input_data = pd.read_csv(dataset, compression='gzip')
    
    for dataset_repeat in range(1, 31):
        # Divide the data set into a training and testing sets, each time with a different RNG seed
        training_indices, testing_indices = next(iter(StratifiedShuffleSplit(input_data['class'].values,
                                                                             n_iter=1,
                                                                             train_size=0.75,
                                                                             test_size=0.25,
                                                                             random_state=dataset_repeat)))
        
        training_features = input_data.loc[training_indices].drop('class', axis=1).values
        training_classes = input_data.loc[training_indices, 'class'].values

        testing_features = input_data.loc[testing_indices].drop('class', axis=1).values
        testing_classes = input_data.loc[testing_indices, 'class'].values
        
        # These are parameters listed in the project document
        max_depth_list = [1, 2, 3, 4, 5, 10, 20, 50, None]
        max_features_list = [0.1, 0.25, 0.5, 0.75, 'sqrt', 'log2', None]
        criterion_list = ['gini', 'entropy']
        
        # For every DecisionTreeClassifier parameter combination...
        for (max_depth, max_features, criterion) in itertools.product(max_depth_list,
                                                                      max_features_list,
                                                                      criterion_list):
            # Create and fit the model on the training data
            clf = DecisionTreeClassifier(max_depth=max_depth, max_features=max_features, criterion=criterion)
            clf.fit(training_features, training_classes)
            
            # Store the model's score with the key (name of data set, model, model parameters)
            all_model_scores[(dataset,
                              'DecisionTreeClassifier',
                              (max_depth, max_features, criterion))].append(clf.score(testing_features,
                                                                                      testing_classes))

# %%
from glob import glob
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import StratifiedShuffleSplit
import itertools
from collections import defaultdict

all_model_scores = defaultdict(list)

# For every data set in the data repository...
for dataset in glob('data/ecoli.csv.gz'):
    # Read the data set into memory
    input_data = pd.read_csv(dataset, compression='gzip')
    
    for dataset_repeat in range(1, 30):
        # Divide the data set into a training and testing sets, each time with a different RNG seed
        training_indices, testing_indices = next(iter(StratifiedShuffleSplit(input_data['class'].values,
                                                                             n_iter=1,
                                                                             train_size=0.75,
                                                                             test_size=0.25,
                                                                             random_state=dataset_repeat)))
        
        training_features = input_data.loc[training_indices].drop('class', axis=1).values
        training_classes = input_data.loc[training_indices, 'class'].values

        testing_features = input_data.loc[testing_indices].drop('class', axis=1).values
        testing_classes = input_data.loc[testing_indices, 'class'].values
        
        # These are parameters listed in the project document
        penalty_list = ['l1','l2']
        C_list = [0.5, 1.0, 2.0, 10.0, 50.0, 100.0]
        
        # For every DecisionTreeClassifier parameter combination...
        for (C, penalty) in itertools.product(C_list, penalty_list):
            # Create and fit the model on the training data
            clf = LogisticRegression(C=C, penalty=penalty)
            clf.fit(training_features, training_classes)
            
            # Store the model's score with the key (name of data set, model, model parameters)
            all_model_scores[(dataset,
                              'LogisticRegression',
                              (C, penalty))].append(clf.score(testing_features,
                                                              testing_classes))

# %%
print(all_model_scores)
# Out:
# defaultdict(<class 'list'>, {})

# %% [markdown]
# Once the analysis is finished running, make sure to store all of the model scores (with their corresponding labels -- data set, classifier, and parameters) to a file!

# %%
import os
import gzip

if not os.path.isdir('benchmark_results'):
    os.mkdir('benchmark_results')

with gzip.open('benchmark_results/DecisionTreeClassifier-benchmarks.tsv.gz', 'wb') as out_file:
    header_text = '\t'.join(['dataset',
                              'model',
                              'parameters',
                              'testing_score']) + '\n'
    out_file.write(header_text.encode('UTF-8'))
    
    for (dataset, model, params) in all_model_scores:
        param_string = ''
        param_string += 'max_depth={},'.format(params[0])
        param_string += 'max_features={},'.format(params[1])
        param_string += 'criterion={}'.format(params[2])
        
        for testing_score in all_model_scores[(dataset, model, params)]:
            out_text = '\t'.join([dataset[5:-7],
                                  model,
                                  param_string,
                                  str(testing_score)]) + '\n'
            out_file.write(out_text.encode('UTF-8'))

# %%
import pandas as pd

pd.read_csv('benchmark_results/DecisionTreeClassifier-benchmarks.tsv.gz', compression='gzip', sep='\t')
# Out:
#      dataset                   model  \
# 0      glass  DecisionTreeClassifier
# 1      glass  DecisionTreeClassifier
# 2      glass  DecisionTreeClassifier
# 3      glass  DecisionTreeClassifier
# 4      glass  DecisionTreeClassifier
# 5      glass  DecisionTreeClassifier
# 6      glass  DecisionTreeClassifier
# 7      glass  DecisionTreeClassifier
# 8      glass  DecisionTreeClassifier
# 9      glass  DecisionTreeClassifier
# 10     glass  DecisionTreeClassifier
# 11     glass  DecisionTreeClassifier
# 12     glass  DecisionTreeClassifier
# 13     glass  DecisionTreeClassifier
# 14     glass  DecisionTreeClassifier
# 15     glass  DecisionTreeClassifier
# 16     glass  DecisionTreeClassifier
# 17     glass  DecisionTreeClassifier
# 18     glass  DecisionTreeClassifier
# 19     glass  DecisionTreeClassifier
# 20     glass  DecisionTreeClassifier
# 21     glass  DecisionTreeClassifier
# 22     glass  DecisionTreeClassifier
# 23     glass  DecisionTreeClassifier
# 24     glass  DecisionTreeClassifier
# 25     glass  DecisionTreeClassifier
# 26     glass  DecisionTreeClassifier
# 27     glass  DecisionTreeClassifier
# 28     glass  DecisionTreeClassifier
# 29     glass  DecisionTreeClassifier
# ...      ...                     ...
# 3750   glass  DecisionTreeClassifier
# 3751   glass  DecisionTreeClassifier
# 3752   glass  DecisionTreeClassifier
# 3753   glass  DecisionTreeClassifier
# 3754   glass  DecisionTreeClassifier
# 3755   glass  DecisionTreeClassifier
# 3756   glass  DecisionTreeClassifier
# 3757   glass  DecisionTreeClassifier
# 3758   glass  DecisionTreeClassifier
# 3759   glass  DecisionTreeClassifier
# 3760   glass  DecisionTreeClassifier
# 3761   glass  DecisionTreeClassifier
# 3762   glass  DecisionTreeClassifier
# 3763   glass  DecisionTreeClassifier
# 3764   glass  DecisionTreeClassifier
# 3765   glass  DecisionTreeClassifier
# 3766   glass  DecisionTreeClassifier
# 3767   glass  DecisionTreeClassifier
# 3768   glass  DecisionTreeClassifier
# 3769   glass  DecisionTreeClassifier
# 3770   glass  DecisionTreeClassifier
# 3771   glass  DecisionTreeClassifier
# 3772   glass  DecisionTreeClassifier
# 3773   glass  DecisionTreeClassifier
# 3774   glass  DecisionTreeClassifier
# 3775   glass  DecisionTreeClassifier
# 3776   glass  DecisionTreeClassifier
# 3777   glass  DecisionTreeClassifier
# 3778   glass  DecisionTreeClassifier
# 3779   glass  DecisionTreeClassifier
#
#                                            parameters  testing_score
# 0        max_depth=5,max_features=0.75,criterion=gini       0.716981
# 1        max_depth=5,max_features=0.75,criterion=gini       0.622642
# 2        max_depth=5,max_features=0.75,criterion=gini       0.679245
# 3        max_depth=5,max_features=0.75,criterion=gini       0.547170
# 4        max_depth=5,max_features=0.75,criterion=gini       0.641509
# 5        max_depth=5,max_features=0.75,criterion=gini       0.603774
# 6        max_depth=5,max_features=0.75,criterion=gini       0.547170
# 7        max_depth=5,max_features=0.75,criterion=gini       0.679245
# 8        max_depth=5,max_features=0.75,criterion=gini       0.660377
# 9        max_depth=5,max_features=0.75,criterion=gini       0.735849
# 10       max_depth=5,max_features=0.75,criterion=gini       0.622642
# 11       max_depth=5,max_features=0.75,criterion=gini       0.698113
# 12       max_depth=5,max_features=0.75,criterion=gini       0.641509
# 13       max_depth=5,max_features=0.75,criterion=gini       0.660377
# 14       max_depth=5,max_features=0.75,criterion=gini       0.603774
# 15       max_depth=5,max_features=0.75,criterion=gini       0.716981
# 16       max_depth=5,max_features=0.75,criterion=gini       0.792453
# 17       max_depth=5,max_features=0.75,criterion=gini       0.622642
# 18       max_depth=5,max_features=0.75,criterion=gini       0.660377
# 19       max_depth=5,max_features=0.75,criterion=gini       0.679245
# 20       max_depth=5,max_features=0.75,criterion=gini       0.566038
# 21       max_depth=5,max_features=0.75,criterion=gini       0.735849
# 22       max_depth=5,max_features=0.75,criterion=gini       0.679245
# 23       max_depth=5,max_features=0.75,criterion=gini       0.566038
# 24       max_depth=5,max_features=0.75,criterion=gini       0.660377
# 25       max_depth=5,max_features=0.75,criterion=gini       0.716981
# 26       max_depth=5,max_features=0.75,criterion=gini       0.698113
# 27       max_depth=5,max_features=0.75,criterion=gini       0.679245
# 28       max_depth=5,max_features=0.75,criterion=gini       0.735849
# 29       max_depth=5,max_features=0.75,criterion=gini       0.622642
# ...                                               ...            ...
# 3750  max_depth=None,max_features=log2,criterion=gini       0.679245
# 3751  max_depth=None,max_features=log2,criterion=gini       0.660377
# 3752  max_depth=None,max_features=log2,criterion=gini       0.641509
# 3753  max_depth=None,max_features=log2,criterion=gini       0.660377
# 3754  max_depth=None,max_features=log2,criterion=gini       0.679245
# 3755  max_depth=None,max_features=log2,criterion=gini       0.584906
# 3756  max_depth=None,max_features=log2,criterion=gini       0.622642
# 3757  max_depth=None,max_features=log2,criterion=gini       0.603774
# 3758  max_depth=None,max_features=log2,criterion=gini       0.603774
# 3759  max_depth=None,max_features=log2,criterion=gini       0.698113
# 3760  max_depth=None,max_features=log2,criterion=gini       0.679245
# 3761  max_depth=None,max_features=log2,criterion=gini       0.735849
# 3762  max_depth=None,max_features=log2,criterion=gini       0.603774
# 3763  max_depth=None,max_features=log2,criterion=gini       0.603774
# 3764  max_depth=None,max_features=log2,criterion=gini       0.698113
# 3765  max_depth=None,max_features=log2,criterion=gini       0.660377
# 3766  max_depth=None,max_features=log2,criterion=gini       0.773585
# 3767  max_depth=None,max_features=log2,criterion=gini       0.433962
# 3768  max_depth=None,max_features=log2,criterion=gini       0.641509
# 3769  max_depth=None,max_features=log2,criterion=gini       0.660377
# 3770  max_depth=None,max_features=log2,criterion=gini       0.528302
# 3771  max_depth=None,max_features=log2,criterion=gini       0.867925
# 3772  max_depth=None,max_features=log2,criterion=gini       0.603774
# 3773  max_depth=None,max_features=log2,criterion=gini       0.603774
# 3774  max_depth=None,max_features=log2,criterion=gini       0.754717
# 3775  max_depth=None,max_features=log2,criterion=gini       0.716981
# 3776  max_depth=None,max_features=log2,criterion=gini       0.754717
# 3777  max_depth=None,max_features=log2,criterion=gini       0.698113
# 3778  max_depth=None,max_features=log2,criterion=gini       0.660377
# 3779  max_depth=None,max_features=log2,criterion=gini       0.811321
#
# [3780 rows x 4 columns]

# %% [markdown]
# Make sure to commit the notebook (with code and annotations) *and* the score data to this repository once the analysis is finished.
